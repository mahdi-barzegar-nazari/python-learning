# %%
my_list = [0, 1, 2, 3]

# %%
animals = ['bird', 'cat', 'lion', 'dog', 3.14, False, 5]

# %%
my_list + animals
# Out:
# [0, 1, 2, 3, 'bird', 'cat', 'lion', 'dog', 3.14, False, 5]

# %%
new_list = my_list * 2

# %%
new_list[4]
# Out:
# 0

# %%
new_list
# Out:
# [0, 1, 2, 3, 0, 1, 2, 3]

# %%
new_list[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 new_list[10
#       2         ]
#
# IndexError: list index out of range

# %%
new_list.count(2)
# Out:
# 2

# %%
new_list.count(20)
# Out:
# 0

# %%
len(new_list)
# Out:
# 8

# %%
new_list.pop()
# Out:
# 3

# %%
new_list
# Out:
# [0, 1, 2, 3, 0, 1, 2]

# %%
animals
# Out:
# ['bird', 'cat', 'lion', 'dog', 3.14, False, 5]

# %%
test = animals.pop()

# %%
test
# Out:
# 5

# %%
animals
# Out:
# ['bird', 'cat', 'lion', 'dog', 3.14, False]

# %%
new_test = animals.pop()

# %%
new_test
# Out:
# 3.14

# %%
animals = ['lion', 'cat', 'bird', 'dog']

# %%
animals
# Out:
# ['lion', 'cat', 'bird', 'dog']

# %%
animals.sort()

# %%
animals
# Out:
# ['bird', 'cat', 'dog', 'lion']

# %%
animals[2] = "fish"

# %%
animals
# Out:
# ['bird', 'cat', 'fish', 'lion']

# %%
animals.remove('cat')

# %%
animals
# Out:
# ['bird', 'fish', 'lion']

# %%
animals.reverse()

# %%
animals
# Out:
# ['lion', 'fish', 'bird']
