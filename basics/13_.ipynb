# %%
myset = set()

# %%
myset.add(2)
myset.add(5)

# %%
myset
# Out:
# {2, 5}

# %%
type(myset)
# Out:
# set

# %%
type(20)
# Out:
# int

# %%
myset.add(1, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 myset.add(1, 3)
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
myset.add([1, 3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 myset.add([1, 3])
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
myset.add('test')

# %%
myset
# Out:
# {2, 5, 'test'}

# %%
math = set()
math.add('reza')
math.add('amir')

# %%
chess = set()
chess.add('amir')
chess.add('hesam')

# %%
math
# Out:
# {'amir', 'reza'}

# %%
chess
# Out:
# {'amir', 'hesam'}

# %%
math.union(chess)
# Out:
# {'amir', 'hesam', 'reza'}

# %%
math.intersection(chess)
# Out:
# {'amir'}

# %%
fruit = set(['apple', 'banana', 'kiwi', 'lemon'])

# %%
fruit
# Out:
# {'apple', 'banana', 'kiwi', 'lemon'}

# %%
type(fruit)
# Out:
# set

# %%
fruit.add('orange')

# %%
fruit
# Out:
# {'apple', 'banana', 'kiwi', 'lemon', 'orange'}

# %%
set = {1, 2}

# %%
set
# Out:
# {1, 2}
