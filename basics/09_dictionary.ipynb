# %%
n = {"orange": 24, "kiwi": 15, "lemon": 8}

# %%
n['kiwi']
# Out:
# 15

# %%
n = {
    "amir": {
        "orange": 4,
        "kiwi": 16,
        "lemon": 9
    },

    "reza": {
        "kiwi": 11,
        "orange": 8,
        "lemon": 3
    }
}

# %%
n["amir"]["lemon"]
# Out:
# 9

# %%
n.keys()
# Out:
# dict_keys(['amir', 'reza'])

# %%
n.values()
# Out:
# dict_values([{'orange': 4, 'kiwi': 16, 'lemon': 9}, {'kiwi': 11, 'orange': 8, 'lemon': 3}])

# %%
n.items()
# Out:
# dict_items([('amir', {'orange': 4, 'kiwi': 16, 'lemon': 9}), ('reza', {'kiwi': 11, 'orange': 8, 'lemon': 3})])

# %%
price = {
    "pear": 60,
    "mango": 100,
    "grape": 80
}

# %%
price.keys()
# Out:
# dict_keys(['pear', 'mango', 'grape'])

# %%
price.keys()
# Out:
# dict_keys(['pear', 'mango', 'grape'])

# %%
price.values()
# Out:
# dict_values([60, 100, 80])

# %%
price.items()
# Out:
# dict_items([('pear', 60), ('mango', 100), ('grape', 80)])

# %%
price.get("mango")
# Out:
# 100

# %%
price.get("peach", -1)
# Out:
# -1

# %%
price.get("grape", -1)
# Out:
# 80

# %%
numbers = {
    "list1": [1, 2, 3, 4],
    "list2": [7, 13, 3.14]
}

# %%
numbers["list2"]
# Out:
# [7, 13, 3.14]

# %%
numbers["list2"][1]
# Out:
# 13

# %%
numbers["list2"][1] + 4
# Out:
# 17
