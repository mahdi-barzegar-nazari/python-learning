# %%
name = "Mahdi"

# %%
age = 99

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
ghad = 198.7

# %%
type(ghad)
# Out:
# float

# %%
'4' + '6'
# Out:
# '46'

# %%
name
# Out:
# 'Mahdi'

# %%
name.lower()
# Out:
# 'mahdi'

# %%
name.upper()
# Out:
# 'MAHDI'

# %%
name.isupper()
# Out:
# False

# %%
name.index('h')
# Out:
# 2

# %%
name.index('H')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 name.index('H')
#
# ValueError: substring not found

# %%
name
# Out:
# 'Mahdi'

# %%
name = name.upper()

# %%
name
# Out:
# 'MAHDI'

# %%
animals = "dog,cat,bird,fish,cow,lion"

# %%
animals
# Out:
# 'dog,cat,bird,fish,cow,lion'

# %%
animals.split(",")
# Out:
# ['dog', 'cat', 'bird', 'fish', 'cow', 'lion']
